# %%
import os
import sys 
import logging 
import numpy as np 
# Load environment variables
from dotenv import load_dotenv
load_dotenv()

from elastic_helpers import ESBulkIndexer, ESQueryMaker
from embedding_model import EmbeddingModel
from llamaindex_processor import LlamaIndexProcessor
from nltk_processor import NLTKProcessor
from chunker import Chunker
from elastic_config import BASIC_CONFIG
from llm import LLMProcessor
from elastic_helpers import ESBulkIndexer
from elastic_config import BASIC_CONFIG
from document_enricher import DocumentEnricher
from entity_extractor import EntityExtractor
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/utils/generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# [nltk_data] Downloading package punkt to /Users/han/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/han/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /Users/han/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/han/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Improvements
# 1. Vector Enrichment by Metadata Recombination of keyphrases and generated questions via weightings
# 2. Sentence wise, token-level chunking with window overlaps
# 3. Match OR string
# 4. HyDE
# 5. Reverse Packing

# %% [markdown]
# <!-- ![](./assets/rag_pipe.png) -->

# %% [markdown]
# # Step One: Initialize services, Initial Setup

# %%
# Configure logging
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S')
logger = logging.getLogger(__name__)

# Initialize Embedding Model
HUGGINGFACE_EMBEDDING_MODEL = os.environ.get('HUGGINGFACE_EMBEDDING_MODEL')
embedder=EmbeddingModel(model_name=HUGGINGFACE_EMBEDDING_MODEL)

# Initialize Document Processors
llamaindex_processor=LlamaIndexProcessor()
nltkprocessor=NLTKProcessor()
chunker=Chunker(embedder.tokenizer)
documentenricher=DocumentEnricher()
entity_extractor=EntityExtractor()

# Initialize Elasticsearch
ELASTIC_CLOUD_HOST = os.environ.get('ELASTIC_CLOUD_HOST')
ELASTIC_USERNAME = os.environ.get('ELASTIC_USERNAME')
ELASTIC_PASSWORD = os.environ.get('ELASTIC_PASSWORD')
ELASTIC_CLOUD_AUTH = (ELASTIC_USERNAME, ELASTIC_PASSWORD)
es_bulk_indexer = ESBulkIndexer(cloud_id=[ELASTIC_CLOUD_HOST], credentials=ELASTIC_CLOUD_AUTH)
es_query_maker = ESQueryMaker(cloud_id=[ELASTIC_CLOUD_HOST], credentials=ELASTIC_CLOUD_AUTH)

# Define Index Name
index_name=os.environ.get('ELASTIC_INDEX_NAME')

# Initialize LLMs
gpt4o = LLMProcessor(model='gpt-4o')
# Out:
# Using MPS
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/utils/generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# INFO:elastic_helpers:Connection created for hosts: ['https://training-9b4cc2.es.asia-southeast1.gcp.elastic-cloud.com:9243/']
# INFO:elastic_helpers:Connection created for hosts: ['https://training-9b4cc2.es.asia-southeast1.gcp.elastic-cloud.com:9243/']
# INFO:llm:LLMProcessor initialized with model: gpt-4o

# %%
es_bulk_indexer.ping()
# Out:
# INFO:elastic_transport.transport:HEAD https://training-9b4cc2.es.asia-southeast1.gcp.elastic-cloud.com:9243/ [status:200 duration:0.042s]
# Ping successful: Connected to Elasticsearch!

# %% [markdown]
# # Step Two: Process some documents

# %%
documents=llamaindex_processor.load_documents('./documents/')
documents=[dict(doc_obj) for doc_obj in documents]

# %%
documents
# Out:
# [Document(id_='9b373033-1af4-4278-9d00-07fa3a340497', embedding=None, metadata={'page_label': '1', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='253288ca-8fb1-402b-bf66-e9391188ccb2', embedding=None, metadata={'page_label': '2', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='93b26452-6060-4daf-926e-eeadb8b240c9', embedding=None, metadata={'page_label': '3', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='UNITED STATES\nSECURITIES AND EXCHANGE COMMISSION\nWashington, D.C. 20549\n_______________________________________________________________ _______________________________________________________________ ______________________________________________________________\nFORM 10-K\n_______________________________________________________________ _______________________________________________________________ ______________________________________________________________\n(Mark One)\n☒ ANNUAL REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT  OF 1934\nFor the fiscal year ended April 30, 2023 \nOR\n☐ TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURI TIES EXCHANGE ACT OF 1934\nFor the transition period from   to\nCommission File Number 001-38675\n_______________________________________________________________ _______________________________________________________________ _______________________________________________________________Elastic N.V.\n(Exact name of registrant as specified in its charter)\n_______________________________________________________________ _______________________________________________________________ ______________________________________________________________\nThe Netherlands Not Applicable\n(State or other jurisdiction of\nincorporation or organization)(I.R.S. Employer\nIdentification No.)\nNot Applicable1\n(Address of principal executive offices, including zip code)\nRegistrant’s telephone number, including area code: Not Applicable1\n_______________________________________________________________ _______________________________________________________________ ______________________________________________________________\nSecurities registered pursuant to Section 12(b) of the Act:\nTitle of each class Trading Symbol(s) Name of each exchange on which registered\nOrdinary shares, Par Value €0.01 Per Share ESTC New York Stock Exchange\nSecurities registered pursuant to Section 12(g) of the Act: None\nIndicate by check mark if the registrant is a well-known seasoned issuer, as defined in Rule 405 of the Securities Act. Yes ☒ No ☐\nIndicate by check mark if the registrant is not required to file reports pursuant to Section 13 or 15(d) of the Act. Yes ☐ No ☒\nIndicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during \nthe preceding 12 months (or for such shorter period that the re gistrant was required to file such reports), and (2) has been subject to such filing requirements for \nthe past 90 days. Yes ☒ No ☐\nIndicate by check mark whether the registrant has submitted ele ctronically every Interactive Data File required to be submitted pursuant to Rule 405 of  \nRegulation S-T (§232.405 of this chapter) during the preceding 12 months (or for such shorter period that the registrant was required to sub mit such  \nfiles). Yes ☒ No ☐\nIndicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, a smaller reporting company, or an \nemerging growth company. See the definitions of “large accelerated filer,” “accelerated f iler,” “smaller reporting company,” and “emerging growth company”  \nin Rule 12b-2 of the Exchange Act.\nLarge accelerated filer ...
#  Document(id_='c3121223-6df9-4b8d-82f2-e1c07cddd820', embedding=None, metadata={'page_label': '4', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='The aggregate market value of the ordinary shares held by non-affiliates of the registrant, based on the closing price of the shares of ordinary shares on the New \nYork Stock Exchange on October 31, 2022 (the last business day of the registrant’s second fiscal quarter), was approximately $6.1 billion.\nAs of May 31, 2023, the registrant had 97,390,886 ordinary shares, par value €0.01 per share, outstanding.\nDOCUMENTS INCORPORATED BY REFERENCE\nPortions of the registrant’s definitive proxy statement relating to the registrant’s 2023 annual general meeting of shareholders are incorporated by reference into \nPart III of this Annual Report on Form 10-K where indicated. Such definitive proxy statement will be filed with the U.S. Securities and Exchange Commission \nwithin 120 days after the end of the registrant’s fiscal year ended April 30, 2023.\n2', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='2239bd15-6dfd-4c86-a369-dd212b157bf0', embedding=None, metadata={'page_label': '5', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Table of Contents\nPage\nPART I\nItem 1. Business 3\n15 Item 1A. Risk Factors\nItem 1B. Unresolved Staff Comments 48\nItem 2. Properties 48\nItem 3. Legal Proceedings 48\nItem 4. Mine Safety Disclosures 48\nPART II\nItem 5. Market for Registrant’s Common Equity, Related Stockholder Matters and Issuer Purchases of \nEquity Securities49\nItem 6. [Reserved] 49\nItem 7. Management’s Discussion and Analysis of Financial Condition and Results of Operations 50\nItem 7A. Quantitative and Qualitative Disclosures About Market Risk 64\nItem 8. Financial Statements and Supplementary Data 66\nItem 9. Changes in and Disagreements With Accountants on Accounting and Financial Disclosure 100\n100\n101Item 9A. Controls and Procedures\nItem 9B. Other Information\nItem 9C. Disclosure Regarding Foreign Jurisdictions That Prevent Inspections 101\nPART III\n102\n102\n102\n102Item 10. Directors, Executive Officers and Corporate Governance\nItem 11. Executive Compensation\nItem 12. Security Ownership of Certain Beneficial Owners and Management, and Related Stockholder Matters  \nItem 13. Certain Relationships and Related Transactions, and Director Independence\nItem 14. Principal Accountant Fees and Services 102\nPART IV\n103\n105Item 15. Exhibits and Financial Statement Schedules  \nItem 16. Form 10-K Summary\nSignatures 106\ni', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='b6cee8ec-0852-418f-91b3-86c2fe759e75', embedding=None, metadata={'page_label': '6', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='[This page intentionally left blank] ', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='9d67b10c-fd92-4480-8b16-a876dcbccb0b', embedding=None, metadata={'page_label': '7', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='General\nUnless the context otherwise indicates, references in this report to the terms “Elastic,” “the Company,” “we,” “our” \nand “us” refer to Elastic N.V. and its subsidiaries. All information presented herein is based on our fiscal calendar. Unless \notherwise stated, references to particular years, quarters, months or periods refer to the Company’s fiscal years ended April 30 \nand the associated quarters, months and periods of those fiscal years. \nTrademarks\nThe Elastic design logo “Elastic” and our other registered or common law trademarks, service marks or trade names \nappearing in this Annual Report on Form 10-K are the property of Elastic N.V. and its subsidiaries. Other trademarks and trade \nnames referred to in this Annual Report on Form 10-K are the property of their respective owners. Solely for convenience, \ntrademarks and trade names referred to in this Annual Report on Form 10-K may appear without the ® or ™ symbols.\nNote Regarding Forward-Looking Statements\nThis Annual Report on Form 10-K contains forward-looking statements within the meaning of Section 27A of the \nSecurities Act of 1933, as amended (the “Securities Act”), and Section 21E of the Securities Exchange Act of 1934, as amended \n(the “Exchange Act”), which statements involve substantial risks and uncertainties. Forward-looking statements generally relate \nto future events or our future financial or operating performance. In some cases, you can identify forward-looking statements \nbecause they contain words such as “may,” “might,” “will,” “should,” “expects,” “plans,” “anticipates,” “could,” “intends,” \n“target,” “projects,” “contemplates,” “believes,” “estimates,” “predicts,” “potential,” or “continue” or the negative of these \nwords or other similar terms or expressions that concern our expectations, strategy, plans, or intentions. Forward-looking \nstatements contained in this Annual Report on Form 10-K include, but are not limited to, statements about:\n• our business strategy and our plan to build our business;\n• the impact of macroeconomic conditions, including declining rates of economic growth, supply chain disruptions,\ninflationary pressures, increased interest rates, and other conditions discussed in this report, on information technology\nspending, sales cycles, and other factors affecting the demand for our offerings and our results of operations;\n• our future financial performance, including our expectations regarding our revenue, cost of revenue, gross profit or\ngross margin, operating expenses (which include changes in sales and marketing, research and development and\ngeneral and administrative expenses), and our ability to achieve and maintain future profitability;\n• our ability to continue to deliver and improve our offerings and successfully develop new offerings;\n• customer acceptance and purchase of our existing offerings and new offerings, including the expansion and adoption\nof our cloud-based offerings;\n• the impact of actions that we are taking to reduce our costs and rebalance investments;\n• the impact of Russia’s invasion of Ukraine on our business and on the businesses of our customers and partners,\nincluding their spending priorities;\n• the effects of the coronavirus disease 2019 (“COVID-19”), on our business and financial result ...
#  Document(id_='60cf5296-c410-4f61-966d-86e7a8865e47', embedding=None, metadata={'page_label': '8', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='• our strategy of acquiring complementary businesses and our ability to successfully integrate acquired businesses and\ntechnologies;\n• the impact of acquisitions on our future product offerings;\n• our beliefs and objectives for future operations;\n• our relationships with and reliance on third parties, including partners;\n• our ability to protect our intellectual property rights;\n• our ability to develop our brands;\n• the impact of expensing stock options and other equity awards;\n• the sufficiency of our capital resources;\n• our ability to successfully defend litigation brought against us;\n• our ability to successfully execute our go-to-market strategy, including the positioning of our solutions and products,\nand to expand in our existing markets and into new markets;\n• sufficiency of cash to meet our cash needs for at least the next 12 months;\n• our ability to comply with laws and regulations that currently apply or may become applicable to our business both in\nthe United States and internationally;\n• our ability to attract and retain qualified employees and key personnel;\n• the effect of the loss of key personnel;\n• our expectations about the impact of natural disasters and public health epidemics and pandemics on our business,\nresults of operations and financial condition;\n• the seasonality of our business;\n• the future trading prices of our ordinary shares;\n• our ability to service our debt obligations; and\nIn addition, statements that “we believe” and similar statements reflect our beliefs and opinions. These statements are\nbased upon information available to us as of the date of this Annual Report on Form 10-K, and while we believe this \ninformation forms a reasonable basis for such statements, the information may be limited or incomplete, and our statements \nshould not be read to indicate that we have conducted an exhaustive inquiry into, or review of, all potentially available relevant \ninformation. These statements are inherently uncertain and investors are cautioned not to unduly rely upon these statements. \nOur forward-looking statements do not reflect the potential impact of any future acquisitions, mergers, dispositions, joint \nventures, or investments we may make.\nYou should not rely upon forward-looking statements expressed or implied by us as predictions of future events. We \nhave based the forward-looking statements contained in this Annual Report on Form 10-K primarily on our current expectations \nregarding future events and trends that we believe may affect our business, financial condition, results of operations, and \nprospects. The outcome of the events described in these forward-looking statements is subject to risks, uncertainties, and other \nfactors described in the section titled “Risk Factors” in Part I, Item 1A and elsewhere in this Annual Report on Form 10-K. \nMoreover, we operate in a very competitive and rapidly changing environment. New risks and uncertainties emerge from time \nto time, and it is not possible for us to predict all risks and uncertainties that could have an impact on the forward-looking \nstatements contained in this report. Actual results, events, or circumstances could differ materially from those described or \nimplied in the forward-looking statements.\nThe forward-looking sta ...
#  Document(id_='2749bdc0-22b6-4902-8460-34774fdc774a', embedding=None, metadata={'page_label': '9', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='PART I\nItem 1. Business\nElastic is a data analytics company built on the power of search. Our platform, which is available as both a hosted, \nmanaged service across public clouds as well as self-managed software, allows our customers to find insights and drive \nartificial intelligence (“AI”) and machine learning use cases from large amounts of data. We offer three search-powered \nsolutions – Search, Observability, and Security – that are built into the platform. We help organizations, their employees, and \ntheir customers find what they need faster, while keeping mission-critical applications running smoothly, and protecting against \ncyber threats. \nAs digital transformation drives mission critical business functions to the cloud, we believe that every company will \nneed to build around a search-based relevance engine to find the answers that matter, from all of their data, in real-time, and at \nscale. \nOur platform is built on the Elastic Stack, a powerful set of software products that ingest data from any source, in any \nformat, and perform search, analysis, and visualization of that data. At the core of the Elastic Stack is Elasticsearch - a highly \nscalable document store and search engine, and the unified data store for all of our solutions and use cases. Another component \nof the Elastic Stack is Kibana, which delivers a common user interface across all of our solutions, with powerful drag-and-drop \nvisual analytics, and centralized management of the platform. Our platform also includes the Elasticsearch Relevance Engine™ \n(“ESRE”), which combines advanced AI with Elastic’s text search to give developers a full suite of sophisticated retrieval \nalgorithms and the ability to integrate with large language models. Our out-of-the-box solutions deliver fast time to value for \ncommon use cases and, paired with our developer-centric platform which is extensible and customizable, allow us to innovate \nfast and differentiate our offerings at every level. \nWe make our platform available as a hosted, managed service across major cloud providers (Amazon Web Services \n(“AWS”), Google Cloud Platform (“GCP”), and Microsoft Azure) in more than 50 public cloud regions globally. Customers \ncan also deploy our platform across hybrid clouds, public or private clouds, and multi-cloud environments. \nOur business model is based primarily on a combination of a paid Elastic-managed hosted service offering and paid \nand free proprietary self-managed software. Our paid offerings for our platform are sold via subscription through resource-\nbased pricing, and all customers and users have access to all solutions. In Elastic Cloud, our family of cloud-based offerings \nunder which we offer our software as a hosted, managed service, we offer various subscription tiers tied to different features. \nFor users who download our software, we make some of the features of our software available for free, allowing us to engage \nwith a broad community of developers and practitioners and introduce them to the value of the Elastic Stack. We believe in the \nimportance of an open software development model, and we develop the majority of our software in public repositories as open \ncode under a proprietary license. Unlike some companies, we do not build an enterprise ver ...
#  Document(id_='389601ee-1462-4989-8098-72c067deb9dc', embedding=None, metadata={'page_label': '10', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='We offer the Elastic Stack, a powerful set of software products that ingest and store data from any source, in any \nformat, and perform search, analysis, and visualization, usually in milliseconds. The Elastic Stack can be used by developers to \npower a variety of use cases. We also offer software solutions built in the Elastic Stack that address a wide variety of use cases. \nThe Elastic Stack and our solutions are designed to run in public or private clouds, in hybrid environments, or in multi-cloud \nenvironments.\nThe Elastic Stack\nThe Elastic Stack is primarily composed of the following products:\n•Elasticsearch.   Elasticsearch is the heart of the Elastic Stack. It is a distributed, real-time search and analytics\nengine and data store for all types of data, including textual, numerical, geospatial, structured, and unstructured.\n•Kibana.   Kibana is the user interface for the Elastic Stack. It is the visualization layer for data stored in\nElasticsearch. It is also the management and configuration interface for all parts of the Elastic Stack.\nElastic has spent years infusing both Elasticsearch and Kibana with a foundation of AI and machine learning built on \nESRE, from support for external machine learning models to native vector search capabilities, supervised and unsupervised \nmachine learning, and solution capabilities that improve search relevance and identify anomalies. Elastic enables organizations \nto integrate generative AI and large language models by building key capabilities into its products.\nThe Elastic Stack also supports data ingest with a number of products:\n•Elastic Agent.   Elastic Agent is a single, unified way to add monitoring for logs, metrics, and other types of data\nto each host. Elastic Agent includes integrated host protection and central management.\n•Beats.   Beats is the family of lightweight, single-purpose data shippers for sending data from edge machines to\nElasticsearch or Logstash.\n•Logstash.   Logstash is the dynamic data processing pipeline for ingesting data into Elasticsearch or other storage\nsystems from a multitude of sources simultaneously.\nPaid proprietary features in the Elastic Stack enable capabilities such as automating anomaly detection on time series \ndata at scale through machine learning, facilitating compliance with data security and privacy regulations, supporting search \nacross low cost cold and frozen data tiers, and allowing real-time notifications and alerts. The source code of features in the \nElastic Stack is generally visible to the public in the form of “open code.”\nOur Solutions\nWe have built a number of solutions into the Elastic Stack to make it easier for organizations to use our software for \ncommon use cases. Our solutions include:\n•Search.  Our Search solution provides powerful search for documents and results living in applications, websites,\nand workplaces. Key use cases for Search include: search applications, a foundation for building search\nexperiences to support websites and portals, e-commerce, mobile app search, and customer support; and\nworkplace search, an out-of-the-box search solution for the workplace that seamlessly connects to the most widely\nused enterprise systems and tools.\n•Observability.  Our Observability solution enables unified analysis a ...
#  Document(id_='2d3a6d4f-c758-4775-bb7b-b61cf5d6f807', embedding=None, metadata={'page_label': '11', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Our Deployment Options\nThe Elastic Stack and our solutions can be deployed in public or private clouds, in hybrid environments, or in multi-\ncloud environments, to satisfy various user and customer needs. Elastic Cloud, our family of cloud-based offerings, is hosted on \nmajor public cloud providers. We also partner with other cloud providers who offer our software to users on their cloud \nplatform as a hosted offering.\nUsers can also download and manage their own deployments of the Elastic Stack and our solutions. To help with more \ncomplex deployment scenarios, we offer paid proprietary products to deliver centralized provisioning, management, and \nmonitoring across multiple deployments.\nStrengths of our Products \nThe strengths of our products include the following: \n•Speed.   The Elastic Stack can find matches for search criteria in milliseconds within even the largest structured\nand unstructured datasets. Its schemaless structure and inverted indices enable real-time search of high volumes of\nstructured, unstructured, and time series data.\n•Scale.   The Elastic Stack is a distributed system and can scale massively. It has the ability to subdivide search\nindices into multiple pieces called shards, which enables data volume to be scaled horizontally and operations to\nbe distributed across hundreds of systems or more. A developer running hundreds of nodes has the same user\nexperience as a developer running a single node on a laptop.\n•Relevance.   Elasticsearch uses multiple analytical techniques, including both traditional and AI-powered\nrelevance techniques, to determine the similarity between stored data and queries, generating highly relevant\nresults reflecting a deep understanding of text and context. Its sophisticated yet developer-friendly query language\npermits advanced search and analytics. Additionally, the speed of the Elastic Stack permits query iteration, further\nenhancing the relevance of search results.\n•Ease of Use.   The Elastic Stack is engineered to take a user from data to dashboard or inquiry to insight in\nminutes. It offers an easy getting-started experience, featuring streamlined download and deployment, sensible\ndefaults, a simple and intuitive query language that just works, and no need to define a schema up front.\nAdministrative tasks such as securing the Elastic Stack are intuitive and integrated into the user experience, as are\ninvestigative tasks such as data visualization.\n•Flexibility.   The Elastic Stack is able to ingest, filter, store, search, and analyze data in any form, whether\nstructured or unstructured. These capabilities enable the Elastic Stack to generate insights from a wide variety of\ndata sources for a broad range of use cases. The flexibility of the Elastic Stack also enables users to begin using\nour products along with their existing systems, which lowers barriers to adoption.\n•Extensibility.   Developers can use the Elastic Stack as a foundation for addressing a wide variety of use cases.\nOur open approach to building the Elastic Stack empowers developers to innovate and utilize it to fit their specific\nneeds. Additionally, our developer community actively engages with us to improve and expand the Elastic Stack.\nOur Growth Strategies \nWe pursue the following growth strategies: \ ...
#  Document(id_='e787018e-265f-418a-9767-4d0b37dfba96', embedding=None, metadata={'page_label': '12', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='•Expand our customer base by acquiring new customers.  Through Elastic Cloud, we provide the fastest and\neasiest way to get started with a free trial. However, there is no free subscription tier in Elastic Cloud. Self-\nmanaged users can easily download our software directly from our website and access many features free of\ncharge, which also facilitates adoption. Our sales and marketing team conducts campaigns to drive further\nawareness and adoption within the user community. As a result, many of our sales prospects are already familiar\nwith our technology prior to entering into a commercial relationship with us. Additionally, we leverage our\nnetwork of partners to drive awareness and expand our sales and marketing reach to target new customers. We\nwill continue to engage our community and our partners to drive awareness and to invest in our sales and\nmarketing team to grow our customer base.\n•Expand within our existing customer base through new use cases and larger deployments.   We view initial\nsuccess with our products as a path to drive expansion to new use cases and projects and larger deployments\nwithin organizations. We often enter an organization through a single developer or a small team for an initial\nproject or use case with an objective to quickly solve a technical challenge or business problem. Because of the\nrapid success with our products, knowledge of Elastic often spreads within an organization to new teams of\ndevelopers, architects, IT operations personnel, security personnel, and senior executives. We will continue to\ninvest in helping users and customers be successful with our products.\n•Extend our product leadership through continued investment in our technology.   We will continue to invest\nin our products and services to extend into new use cases, industries, geographies, and customers. We regularly\ndeliver new and enhanced capabilities to our customers through regular releases, to which everyone has access\nbased on our subscription model. Our technology investments within the Elastic Stack include foundational\ncapabilities as well as solution enhancements for our target use cases.\n•Expand our strategic and regional partnerships.   Our partners assist us in driving awareness of Elastic and our\nproducts, using the Elastic Stack to solve customer pain points, and extending our reach in geographic areas and\nverticals where we do not have a formal sales presence. We have a diverse range of partners and we will continue\nto pursue partnerships to further the development of the Elastic Stack and our customer reach.\n•Selectively pursue strategic acquisitions.   Since inception, we have selectively pursued strategic acquisitions to\ndrive product and market expansion. The focus of our most recent acquisitions has been to enhance the technology\nunderlying our Security and Observability offerings. We intend to continue to pursue acquisitions selectively.\nCustomers\nOrganizations of all sizes, across many industries, including enterprises, educational institutions and government \nentities, purchase our products for a variety of use cases. As of April 30, 2023, we had approximately 20,200 customers \ncompared to over 18,600 customers and over 15,000 customers as of April 30, 2022 and 2021, respectively. No customer \nacco ...
#  Document(id_='53c3ada0-57f6-4739-b813-b4d26094ef0e', embedding=None, metadata={'page_label': '13', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='We intend to continue to invest in our research and development capabilities to extend our products. Research and \ndevelopment expense totaled $313.5 million and $273.8 million for the years ended April 30, 2023 and 2022, respectively. We \nplan to continue to devote significant resources to research and development. \nSales and Marketing \nWe make it easy for users to begin using our products in order to drive rapid adoption. Users can either sign up for a \nfree trial on Elastic Cloud or download our software directly from our website without any sales interaction, and immediately \nbegin using the full set of features. Users can also sign up for Elastic Cloud through public cloud marketplaces.\nWith our business model, where users can download and use many of our features for free, our sales prospects are \noften already familiar with or using our platform. We conduct low-touch campaigns to keep users and customers engaged once \nthey have begun using Elastic Cloud or have downloaded our software. This process includes providing high-quality content, \ndocumentation, webinars, videos, and blogs through our website. We also drive high-touch engagement with qualified \nprospects and customers to drive further awareness, adoption, and expansion of our products with paid subscriptions. The \nmajority of our new customers use Elastic Cloud. Many of these customers start with limited initial spending, but can \nsignificantly grow their spending.\nOur sales teams are organized primarily by geography and secondarily by customer segments. We rely on inside sales \ndevelopment representatives to qualify leads based on the likelihood they will result in a purchase. We pursue sales \nopportunities both through our direct sales force and as assisted by our partners, including through cloud marketplaces. Our \nrelationships within customer organizations often extend beyond the initial users of the technology and include technology and \nbusiness decision-makers at various levels. We also engage with our customers on an ongoing basis through a customer success \nteam, to ensure customer satisfaction and expand their usage of our technology. \nPartners\nWe maintain partner relationships that help us market and deliver our products to our customers and complement our \ncommunity. Our partner relationships include the following:\n• Cloud providers.   We work with many of the major cloud providers to increase awareness of our products and\nmake it easy to access our software. We partner with Amazon, Google, and Microsoft to offer Elastic Cloud on\nAWS, GCP, and Microsoft Azure, through direct purchase from us or their respective marketplaces. We also\npartner with other cloud providers to offer our free and paid proprietary features to users on their cloud platforms.\n• Systems integrators, channel partners, and referral partners.   We have a global network of systems\nintegrators, channel partners, and referral partner relationships that help deliver our products to various business\nand government customers around the world.\n• OEM and MSP partners.   Our original equipment manufacturing (“OEM”) and managed service provider\n(“MSP”) partners embed an Elastic subscription into the products or services they offer to their customers. OEM\nor MSP partners are able to include  ...
#  Document(id_='74af1ccb-acb9-4b1f-866d-209e717d15f8', embedding=None, metadata={'page_label': '14', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='However, in many situations, such as those involving complex enterprise IT environments, large deployments and \nnovel use cases, our users require our support. Accordingly, we include support as part of the subscriptions we sell for our \nproducts. Our global support organization consists of engineers who provide technical support services including \ntroubleshooting, technical audits, cluster tuning, and upgrade assistance. Our support team is distributed across over 20 \ncountries and provides coverage 24 hours per day, 365 days per year, across multiple languages. \nWe believe that software companies should not have incentives to build low-quality software. In that connection, we \ndo not sell support separately from our software subscriptions. \nOur Technology \nOur platform consists of the Elastic Stack, our solutions, and software that supports our various deployment \nalternatives. Because our solutions are built into the Elastic Stack, innovations and new capabilities in the Elastic Stack may \nbenefit many of our solutions. Our customers can customize and extend our solutions to fit their needs by leveraging the power \nof the Elastic Stack and our developer capabilities.\nTechnology Features of the Elastic Stack\nElasticsearch is the heart of the Elastic Stack, where users store, search, and analyze data. Key features of \nElasticsearch include the following:\n•Store any type of data.  Elasticsearch combines powerful parts of traditional search engines, such as an inverted\nindex to power fast full text search and a column store for analytics, with native support for a wide range of data\ntypes, including text, dates, numbers, geospatial data, date/numeric ranges, and IP addresses. With sensible\ndefaults, and no upfront schema definition necessary, Elasticsearch makes it easy to start simple and fine-tune as\ndatasets grow.\n•Vector search.  Elastic natively supports vector search as part of ESRE, which enables a wide range of advanced\nsearch use cases that improve relevance, including sophisticated search ranking, image search, question\nanswering, and more. Vector search relies on a next generation of machine learning models that can represent\nmany types of content as vectors, including text, images, events, and more. ESRE also supports integration with\nlarge language models. As data volumes and formats explode, this sophisticated approach to search and relevance\nis becoming important for use cases where delivering maximum relevance is critical.\n•Machine learning, AI, and alerting.   Machine learning capabilities such as anomaly detection, forecasting, and\ncategorization are tightly integrated with the Elastic Stack to automatically model the behavior of data, such as\ntrends and periodicity, in real time in order to identify issues faster, streamline root cause analysis, and reduce\nfalse positives. Without these capabilities, it can be very difficult to identify issues such as infrastructure problems\nor intruders in real time across complex, high-volume, fast-moving datasets. In the last few years, we have also\nadded native support for vector search and model management for advanced machine learning models.\n•Powerful query languages.  The Elasticsearch query domain specific language is a flexible, expressive search\nlanguage that expo ...
#  Document(id_='aa389201-56fd-4e51-90e0-f036c60dcc5f', embedding=None, metadata={'page_label': '15', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='•High scale and availability.   Elasticsearch is designed to scale horizontally and be resilient to node or hardware\nfailures. As nodes join a cluster, data is automatically re-balanced and queries and indexing are spread across the\nnew nodes seamlessly. This makes it easy to add hardware to increase indexing throughput or improve query\nthroughput. Elasticsearch also detects node failures and hardware or network issues and automatically protects\nuser data by ejecting the failing or inaccessible nodes and creating new replicas of the data.\n•Security.  Security features give administrators the rights to grant specific levels of access to their various types of\nusers, such as IT, operations, and application teams. Elasticsearch serves as the central authentication hub for the\nentire Elastic Stack. Security features include encrypted communications and encryption-at-rest; role-based access\ncontrol; single sign-on and authentication; field-level, attribute-level, and document-level security; and audit\nlogging.\nKibana is the user interface for the Elastic Stack. It allows users to manage the Elastic Stack and visualize data. \nAdditionally, the interfaces for many of our solutions are built into Kibana. Key features of Kibana include the following:\n•Explore and visualize data stored in Elasticsearch.  Kibana provides interactive data views, visualizations, and\ndashboards powered by structured filtering and unstructured search to enable users to get to answers more quickly.\nA variety of data visualization types, such as simple line and bar charts, purpose-built geospatial and time series\nvisualizations, tree diagrams, network diagrams, heatmaps, scatter plots, and histograms, support diverse user\nneeds.\n•Incorporate advanced analytics and machine learning from Elasticsearch.  Kibana’s query, filtering, and data\nsummarization capabilities reflect Elasticsearch’s powerful query domain specific language and aggregation\nframework while making it interactive.\n•Manage the Elastic Stack.   Kibana presents a broad user interface showing the health of Elastic Stack\ncomponents and provides cluster alerts to notify administrators of problems. Its central management user\ninterfaces (“UI”) make it easier to operate the Elastic Stack at scale.\n•Home for Solutions.  Kibana is where our users and customers access the user interfaces for our Search,\nObservability, and Security solutions. Kibana provides core services, like security, alerting, and data visualization\ncomponents. This makes it easy for users to discover all of the capabilities our solutions provide, and enables\nsolution users to benefit from Kibana’s core capabilities.\n•Application framework.  Kibana is designed to be extensible. Users interested in a highly specialized\nvisualization type not distributed with Kibana by default can customize experiences through a Kibana plugin and\nmake the plugin available to the community. Dozens of Kibana plugins have been shared by the community via\nElastic documentation and code sharing platforms such as GitHub.\nElastic Agent, Beats, and Logstash are data ingestion tools that enable users to collect and enrich any kind of data from \nany source for storage in Elasticsearch. Beats and Logstash have an extensible modular architecture. Elastic Agent is a s ...
# ...
#  Document(id_='55198217-8379-4084-ba58-28168cd6e7f6', embedding=None, metadata={'page_label': '109', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='PART IV\nItem 15. Exhibits and Financial Statement Schedules\n(a)(1) Financial Statements\nSee Index to Financial Statements in Part I, Item 8 of this Annual Report on Form 10-K.\n(a)(2) Financial Statement Schedules\nAll financial statement schedules have been omitted as the information is not required under the related instructions or \nis not applicable or because the information required is already included in the financial statements or the notes to those \nfinancial statements.\n(a)(3) Exhibits\nWe have filed or incorporated by reference the exhibits listed on the accompanying Exhibit Index.\nExhibit Index\nIncorporated by Reference\nExhibit No. Description of Exhibit Form File No. Exhibit Filing DateFiled \nHerewith\n3.1 10-Q 001-38675 3.1 12/12/2018\n3.2 10-Q 001-38675 3.2 12/12/2018\n3.3 10-Q 001-38675 3.3 12/12/2018\n4.1 S-1 333-227191 4.1 9/5/2018\n4.2 10-K 001-38675 4.2 6/28/2019\n4.3 8-K 001-38675 4.1
section 302 of the Sarbanes-Oxley Act \nof 2002.\nCertification of Principal Executive Officer \npursuant to 18 U.S.C. Section 1350, as adopted \npursuant to Section 906 of the Sarbanes-Oxley Act \nof 2002.\nCertification of Principal Financial Officer \npursuant to 18 U.S.C. Section 1350, as adopted \npursuant to Section 906 of the Sarbanes-Oxley Act \nof 2002.X\n101.INS X\n101.SCH X\n101.CAL X\n101.DEF X\n101.LAB X\n101.PRE X\n104Inline XBRL Instance Document - the instance \ndocument does not appear in the Interactive Data \nFile because its XBRL tags are embedded within \nthe Inline XBRL document. \nInline XBRL Taxonomy Extension Schema \nDocument.\nInline XBRL Taxonomy Extension Calculation \nLinkbase Document.\nInline XBRL Taxonomy Extension Definition \nLinkbase Document.\nInline XBRL Taxonomy Extension Label Linkbase \nDocument.\nInline XBRL Taxonomy Extension Presentation \nLinkbase Document.\nThe cover page from Elastic N.V.’s Annual Report \non Form 10-K for the fiscal year ended April 30, \n2023 formatted in Inline XBRL (included as \nExhibit 101).X\n+ Indicates a management contract or compensatory plan or arrangement.\n104', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='832a4ef7-c3a9-4e41-ad3d-bad8c6929379', embedding=None, metadata={'page_label': '111', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='* The certifications attached as Exhibits 32.1 and 32.2 hereto accompany this Annual Report on Form 10-K pursuant to\n18 U.S.C. Section 1350, as adopted pursuant to Section 906 of the Sarbanes-Oxley Act of 2002, and shall not be\ndeemed “filed” by the Registrant for purposes of Section 18 of the Securities Exchange Act of 1934, as amended, or\nthe Exchange Act, and are not to be incorporated by reference into any of the Registrant’s filings under the Securities\nAct, irrespective of any general incorporation language contained in any such filing.\nItem 16. Form 10-K Summary\nNone.\n105', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='11a9c1b9-d95e-42b3-84b3-22f704287c7b', embedding=None, metadata={'page_label': '112', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='SIGNATURES\nPursuant to the requirements of Section 13 or 15(d) of the Securities Exchange Act of 1934, as amended, the registrant \nhas duly caused this report to be signed on its behalf by the undersigned, thereunto duly authorized.\nElastic N.V.\nDate: June 16, 2023 By: /s/ Ashutosh Kulkarni\nAshutosh Kulkarni\nChief Executive Officer and Director\n(Principal Executive Officer )\nPOWER OF ATTORNEY\nKNOW ALL PERSONS BY THESE PRESENTS, that each person whose signature appears below constitutes and \nappoints Ashutosh Kulkarni and Janesh Moorjani, and each of them, as his or her true and lawful attorney-in-fact and agent \nwith full power of substitution and resubstitution, for such individual in any and all capacities, to sign any and all amendments \nto this Annual Report on Form 10-K, and to file the same, with all exhibits thereto and other documents in connection \ntherewith, with the Securities and Exchange Commission, granting unto said attorneys-in-fact and agents, and each of them, full \npower and authority to do and perform each and every act and thing requisite and necessary to be done in connection therewith, \nas fully for all intents and purposes as he or she might or could do in person, hereby ratifying and confirming all that said \nattorneys-in-fact and agents, or any of them, or the individual’s substitute, may lawfully do or cause to be done by virtue hereof.\nPursuant to the requirements of the Securities Exchange Act of 1934, as amended, this report has been signed below \nby the following persons on behalf of the registrant in the capacities and on the dates indicated.\nName Title Date\n/s/ Ashutosh KulkarniChief Executive Officer and Director (Principal \nExecutive Officer) June 16, 2023\nAshutosh Kulkarni\n/s/ Janesh MoorjaniChief Financial Officer and Chief Operating \nOfficer (Principal Financial and Accounting \nOfficer) June 16, 2023\nJanesh Moorjani\n/s/ Shay Banon Chief Technology Officer and Director June 16, 2023\nShay Banon\n/s/ Chetan Puttagunta Chairman and Director June 16, 2023\nChetan Puttagunta\n/s/ Sohaib Abbasi Director June 16, 2023\nSohaib Abbasi\n/s/ Jonathan Chadwick Director June 16, 2023\nJonathan Chadwick\n/s/ Alison Gleeson Director June 16, 2023\nAlison Gleeson\n/s/ Shelley Leibowitz Director June 16, 2023\nShelley Leibowitz\n/s/ Caryn Marooney Director June 16, 2023\nCaryn Marooney\n/s/ Steven Schuurman Director June 16, 2023\nSteven Schuurman\n106', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='dcd7e35f-8733-4215-80da-603471416ff5', embedding=None, metadata={'page_label': '113', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='619bf960-481e-41c8-bce0-041013a6c6fe', embedding=None, metadata={'page_label': '114', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='5e88833c-3df9-418d-89a4-6f838b0e9f48', embedding=None, metadata={'page_label': '115', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='2d675795-856b-48a4-94be-e0b8932dfb5e', embedding=None, metadata={'page_label': '116', 'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf', 'file_type': 'application/pdf', 'file_size': 3724426, 'creation_date': '2024-07-27', 'last_modified_date': '2024-07-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')]

# %%
chunked_documents=chunker.sentence_wise_tokenized_chunk_documents(documents, chunk_size=512)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (647 > 512). Running this sequence through the model will result in indexing errors

# %%
print(chunked_documents[4]['original_text'])
# Out:
# [CLS] the aggregate market value of the ordinary shares held by non - affiliates of the registrant, based on the closing price of the shares of ordinary shares on the new york stock exchange on october 31, 2022 ( the last business day of the registrant ’ s second fiscal quarter ), was approximately $ 6. 1 billion. [SEP] [CLS] as of may 31, 2023, the registrant had 97, 390, 886 ordinary shares, par value €0. 01 per share, outstanding. [SEP] [CLS] documents incorporated by reference portions of the registrant ’ s definitive proxy statement relating to the registrant ’ s 2023 annual general meeting of shareholders are incorporated by reference into part iii of this annual report on form 10 - k where indicated. [SEP] [CLS] such definitive proxy statement will be filed with the u. s. [SEP] [CLS] securities and exchange commission within 120 days after the end of the registrant ’ s fiscal year ended april 30, 2023. [SEP] [CLS] 2 [SEP]

# %%
# embedder.get_embeddings_from_tokens([chunked_documents[0]['chunk']])

# %% [markdown]
# # Step Three: Enrich your documents

# %%
import pickle

with open('./backups/embedding_generated_questions_0.pkl', 'rb') as f:
    chunked_documents=pickle.load(f)

# %%
processors=[
    (nltkprocessor.textrank_phrases, "keyphrases"),
    # (gpt4o.generate_questions, "potential_questions"),
    (entity_extractor.extract_entities, "entities")
    ]
documentenricher.enrich_document(chunked_documents, text_col='original_text', processors=processors)
# Out:
# Enriching documents using processors: [(<bound method NLTKProcessor.textrank_phrases of <nltk_processor.NLTKProcessor object at 0x32fc4f5f0>>, 'keyphrases'), (<bound method EntityExtractor.extract_entities of <entity_extractor.EntityExtractor object at 0x32fcd4680>>, 'entities')]: 100%|██████████| 224/224 [00:09<00:00, 22.92it/s]

# %%
print(chunked_documents[29]['keyphrases'])
# Out:
# sep cl principal
# sep cl elastic
# cl elastic community
# elastic community code
# community code conduct
# sep cl community
# cl community u
# community u ability
# u ability candid
# ability candid feedback

# %% [markdown]
# # Step Four: Weighted Embeddings

# %%
cols_to_embed=['keyphrases', 'potential_questions', 'entities']

embedding_cols=[]
for col in cols_to_embed:
    embedding_col=embedder.embed_documents_text_wise(chunked_documents, text_field=col)
    embedding_cols.append(embedding_col)
embedding_col=embedder.embed_documents_token_wise(chunked_documents, token_field="chunk")
embedding_cols.append(embedding_col)
# Out:
# Embedding documents: 100%|██████████| 7/7 [00:03<00:00,  2.15it/s]
# Embedding documents: 100%|██████████| 7/7 [00:12<00:00,  1.82s/it]
# Embedding documents: 100%|██████████| 7/7 [00:13<00:00,  1.99s/it]
# Embedding documents: 100%|██████████| 7/7 [00:04<00:00,  1.44it/s]

# %%
import pickle

with open('./backups/embedding_generated_questions_0.pkl', 'wb') as f:
    pickle.dump(chunked_documents, f)

# %%
embedding_cols
# Out:
# ['keyphrases_embedding',
#  'potential_questions_embedding',
#  'entities_embedding',
#  'chunk_embedding']

# %%
embedding_cols=[
                'keyphrases_embedding',
                'potential_questions_embedding',
                'entities_embedding',
                'chunk_embedding']
combination_weights=[
                    0.1,
                    0.15,
                    0.05,
                    0.7
                ]

# %%
from tqdm import tqdm 
def combine_embeddings(objects, embedding_cols, combination_weights, primary_embedding='primary_embedding'):
    # Ensure the number of weights matches the number of embedding columns
    assert len(embedding_cols) == len(combination_weights), "Number of embedding columns must match number of weights"
    
    # Normalize weights to sum to 1
    weights = np.array(combination_weights) / np.sum(combination_weights)
    
    for obj in tqdm(objects, desc="Combining embeddings"):
        # Initialize the combined embedding
        combined = np.zeros_like(obj[embedding_cols[0]])
        
        # Compute the weighted sum
        for col, weight in zip(embedding_cols, weights):
            combined += weight * np.array(obj[col])
        
        # Add the new combined embedding to the object
        obj.update({primary_embedding:combined.tolist()})
        
        # Remove the original embedding columns
        for col in embedding_cols:
            obj.pop(col, None)

# %%
combine_embeddings(chunked_documents, embedding_cols, combination_weights)
# Out:
# Combining embeddings: 100%|██████████| 224/224 [00:00<00:00, 8449.03it/s]

# %%
chunked_documents[3]
# Out:
# {'id_': '7fe71686-5cd0-4831-9e79-998c6dbeae0c',
#  'chunk': [2312,
#   14613,
#   5371,
#   2099,
#   100,
#   14613,
#   5371,
#   2099,
#   100,
#   2512,
#   1011,
#   14613,
#   5371,
#   2099,
#   100,
#   3760,
#   7316,
#   2194,
#   100,
#   8361,
#   3930,
#   2194,
#   100,
#   2065,
#   2019,
#   8361,
#   3930,
#   2194,
#   1010,
#   5769,
#   2011,
#   4638,
#   2928,
#   2065,
#   1996,
#   20588,
#   6494,
#   3372,
#   2038,
#   2700,
#   2025,
#   2000,
#   2224,
#   1996,
#   3668,
#   6653,
#   2558,
#   2005,
#   14037,
#   2075,
#   2007,
#   2151,
#   2047,
#   2030,
#   8001,
#   3361,
#   9529,
#   4781,
#   3024,
#   27081,
#   2000,
#   2930,
#   2410,
#   1006,
#   1037,
#   1007,
#   1997,
#   1996,
#   3863,
#   2552,
#   1012,
#   102,
#   101,
#   100,
#   5769,
#   2011,
#   4638,
#   2928,
#   3251,
#   1996,
#   20588,
#   6494,
#   3372,
#   2038,
#   6406,
#   1037,
#   16360,
#   2953,
#   1056,
#   2006,
#   1998,
#   2012,
#   22199,
#   3370,
#   2000,
#   2049,
#   2968,
#   1521,
#   1055,
#   7667,
#   1997,
#   1996,
#   1041,
#   16020,
#   14931,
#   3512,
#   2791,
#   1997,
#   2049,
#   4722,
#   2491,
#   2058,
#   3361,
#   7316,
#   2104,
#   2930,
#   24837,
#   1006,
#   1038,
#   1007,
#   1997,
#   1996,
#   18906,
#   27543,
#   2015,
#   1011,
#   23060,
#   3051,
#   2552,
#   1006,
#   2321,
#   1057,
#   1012,
#   1055,
#   1012,
#   1039,
#   1012,
#   102,
#   101,
#   5824,
#   2575,
#   2475,
#   1006,
#   1038,
#   1007,
#   1007,
#   2011,
#   1996,
#   5068,
#   2270,
#   9529,
#   3813,
#   2008,
#   17463,
#   2024,
#   2094,
#   2030,
#   3843,
#   2049,
#   15727,
#   3189,
#   1012,
#   102,
#   101,
#   100,
#   2065,
#   12012,
#   2024,
#   5068,
#   27081,
#   2000,
#   2930,
#   2260,
#   1006,
#   1038,
#   1007,
#   1997,
#   1996,
#   2552,
#   1010,
#   5769,
#   2011,
#   4638,
#   2928,
#   3251,
#   1996,
#   3361,
#   8635,
#   1997,
#   1996,
#   20588,
#   6494,
#   3372,
#   2443,
#   1999,
#   1996,
#   15242,
#   8339,
#   1996,
#   18140,
#   1997,
#   2019,
#   7561,
#   2000,
#   3130,
#   3843,
#   10346,
#   2319,
#   6895,
#   2632,
#   8635,
#   1012,
#   102,
#   101,
#   100,
#   5769,
#   2011,
#   4638,
#   2928,
#   3251,
#   2151,
#   1997,
#   2216,
#   7561,
#   20983,
#   2024,
#   2717,
#   3686,
#   8163,
#   2008,
#   3223,
#   1037,
#   7233,
#   4106,
#   1997,
#   20438,
#   1011,
#   2241,
#   9430,
#   2363,
#   2011,
#   2151,
#   1997,
#   1996,
#   20588,
#   6494,
#   3372,
#   1521,
#   1055,
#   3237,
#   3738,
#   2076,
#   1996,
#   7882,
#   7233,
#   2558,
#   27081,
#   2000,
#   1073,
#   11212,
#   1012,
#   2184,
#   2094,
#   1011,
#   1015,
#   1006,
#   1038,
#   1007,
#   1012,
#   102,
#   101,
#   100,
#   5769,
#   2011,
#   4638,
#   2928,
#   3251,
#   1996,
#   20588,
#   6494,
#   3372,
#   2003,
#   1037,
#   5806,
#   4012,
#   9739,
#   1061,
#   1006,
#   2004,
#   4225,
#   1999,
#   3627,
#   2260,
#   2497,
#   1011,
#   1016,
#   1997,
#   1996,
#   3863,
#   2552,
#   1007,
#   1012,
#   102,
#   101,
#   2748,
#   100,
#   2053,
#   100,
#   1015,
#   2057,
#   2024,
#   1037,
#   5500,
#   2194,
#   1012,
#   102,
#   101,
#   11914,
#   1010,
#   2057,
#   2079,
#   2025,
#   2031,
#   1037,
#   4054,
#   3237,
#   2436,
#   1012,
#   102,
#   101,
#   2005,
#   5682,
#   1997,
#   12646,
#   2007,
#   12711,
#   5918,
#   1997,
#   1996,
#   12012,
#   2552,
#   1997,
#   4537,
#   1010,
#   2004,
#   13266,
#   1010,
#   2030,
#   1996,
#   12012,
#   2552,
#   1998,
#   2930,
#   2538,
#   2063,
#   1997,
#   1996,
#   12012,
#   3863,
#   2552,
#   1997,
#   4579,
#   1010,
#   2004,
#   13266,
#   1010,
#   2030,
#   1996,
#   3863,
#   2552,
#   1010,
#   2151,
#   18668,
#   4807,
#   3223,
#   2000,
#   2022,
#   2741,
#   2000,
#   2256,
#   4054,
#   3237,
#   4822,
#   2089,
#   2022,
#   2856,
#   2000,
#   1996,
#   10373,
#   4769,
#   20868,
#   1030,
#   3449,
#   14083,
#   24582,
#   1012,
#   2522,
#   1012,
#   102],
#  'original_text': 'large accelerated filer [UNK] accelerated filer [UNK] non - accelerated filer [UNK] smaller reporting company [UNK] emerging growth company [UNK] if an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying with any new or revised financial accounting standards provided pursuant to section 13 ( a ) of the exchange act. [SEP] [CLS] [UNK] indicate by check mark whether the registrant has filed a repor t on and attestation to its management ’ s assessment of the effe ctiveness of its internal control over financial reporting under section 404 ( b ) of the sarbanes - oxley act ( 15 u. s. c. [SEP] [CLS] 7262 ( b ) ) by the registered public accounting firm that prep ared or issued its audit report. [SEP] [CLS] [UNK] if securities are registered pursuant to section 12 ( b ) of the act, indicate by check mark whether the financial statements of the registrant included in the filing reflect the correction of an error to previously issued financi al statements. [SEP] [CLS] [UNK] indicate by check mark whether any of those error corrections are restatements that required a recovery analysis of incentive - based compensation received by any of the registrant ’ s executive officers during the relevant recovery period pursuant to § 240. 10d - 1 ( b ). [SEP] [CLS] [UNK] indicate by check mark whether the registrant is a shell compan y ( as defined in rule 12b - 2 of the exchange act ). [SEP] [CLS] yes [UNK] no [UNK] 1 we are a distributed company. [SEP] [CLS] accordingly, we do not have a principal executive office. [SEP] [CLS] for purposes of compliance with applicable requirements of the securities act of 1933, as amended, or the securities act and section 21e of the securities exchange act of 1934, as amended, or the exchange act, any shareholder communication required to be sent to our principal executive offices may be directed to the email address ir @ elast ic. co. [SEP]',
#  'chunk_index': 3,
#  'parent_id': '8df63d97-0940-4965-8a59-6aeed7512790',
#  'chunk_token_count': 399,
#  'metadata': {'page_label': '3',
#   'file_name': 'Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf',
#   'file_path': '/Users/han/Desktop/Projects/truckasaurus/documents/Elastic_NV_Annual-Report-Fiscal-Year-2023.pdf',
#   'file_type': 'application/pdf',
#   'file_size': 3724426,
#   'creation_date': '2024-07-27',
#   'last_modified_date': '2024-07-27'},
#  'excluded_embed_metadata_keys': ['file_name',
#   'file_type',
#   'file_size',
#   'creation_date',
#   'last_modified_date',
#   'last_accessed_date'],
#  'excluded_llm_metadata_keys': ['file_name',
#   'file_type',
#   'file_size',
#   'creation_date',
#   'last_modified_date',
#   'last_accessed_date'],
#  'relationships': {},
#  'mimetype': 'text/plain',
#  'start_char_idx': None,
#  'end_char_idx': None,
#  'text_template': '{metadata_str}\n\n{content}',
#  'metadata_template': '{key}: {value}',
#  'metadata_seperator': '\n',
#  'keyphrases': 'sep cl unk\ncheck mark registrant\ncl unk indicate\nunk indicate check\nindicate check mark\nprincipal executive office\naccelerate filer unk\ncompany unk emerge\nunk emerge growth\nemerge growth company',
#  'potential_questions': '1. What are the different types of registrant statuses mentioned in the document?\n2. Under what section of the Sarbanes-Oxley Act must registrants file a report on the effectiveness of their internal control over financial reporting?\n3. According to the document, what should a registrant indicate by check mark if they are an emerging growth company?\n4. Where should shareholder communications intended for the principal executive offices be directed, in accordance with the document?\n5. What must registrants indicate by check mark if their securities are registered pursuant to section 12(b) of the Exchange Act?\n6. What section of the Exchange Act is associated with the requirement to indicate any restatements that required a recovery analysis of incentive-based compensation?\n7. Define a shell company as it is used in the context of this document.\n8. Explain how a registrant must comply with financial accounting standards according to section 13(a) of the Exchange Act.\n9. What specific action related to error corrections in financial statements must registrants disclose, as required by the document?\n10. Discuss how being a distributed company affects the principal executive office location and communication as stated in the document.',
#  'entities': 'the effe ctiveness of\nsection 13\nSEP\nUNK\nsection 21e\n1934\n1933\nu. s. c.\nsection 404\nsection 12\nal',
#  'primary_embedding': [-0.3946287803351879,
#   -0.17586839850991964,
#   0.034158663451671595,
#   0.0732685636729002,
#   -0.03275274336338043,
#   0.03316961328964681,
#   0.3228367581963539,
#   -0.29453448653221126,
#   -0.02405378557741641,
#   -0.00398971252143383,
#   0.375242469087243,
#   -0.02380653247237205,
#   -0.06695218123495578,
#   -0.021980454307049514,
#   -0.2335732586681843,
#   -0.11225923299789428,
#   -0.013347894512116912,
#   -0.29706623703241347,
#   0.11227239221334456,
#   0.29215185195207594,
#   0.4270311683416367,
#   -0.5642538830637931,
#   0.1978787751868367,
#   0.15231543835252523,
#   0.37285702563822265,
#   0.22893275022506712,
#   -0.39581981897354124,
#   -0.19141698665916917,
#   -0.9484765619039535,
#   -1.4041720032691956,
#   -0.16478271409869194,
#   -0.4405265979468822,
#   0.1103836067020893,
#   -0.00607122778892516,
#   0.49572582691907885,
#   -0.06828006505966186,
#   -0.2940201099961996,
#   0.2736325331032276,
#   -0.0813817024230957,
#   0.030897293984889978,
#   -0.23323974944651124,
#   0.30387108549475667,
#   0.2332309067249298,
#   0.010098915547132492,
#   -0.08213046938180923,
#   -0.37156138997524973,
#   -0.13557002320885658,
#   -0.007621875219047065,
#   -0.1851571910083294,
#   0.0877749165520072,
#   0.05154883153736591,
#   -0.21271340325474739,
#   0.31477472465485334,
#   0.13415541127324104,
#   -0.33742301538586617,
#   0.44441872145980593,
#   0.24192345887422562,
#   0.2199809119105339,
#   0.3883186563849449,
#   -0.003276199474930769,
#   0.5133850499987602,
#   0.3395771265029907,
#   -2.416918659210205,
#   -0.127986241877079,
#   0.28178502172231673,
#   0.14074988067150115,
#   -0.14198443591594695,
#   -0.46143450438976286,
#   -0.2406885728240013,
#   0.26938407123088837,
#   0.05105640590190888,
#   -0.2873879551887512,
#   -0.15477032810449598,
#   0.5162370547652244,
#   0.18760755211114882,
#   -0.48043130636215203,
#   0.3509362407028675,
#   0.348240178078413,
#   -0.3935575406998396,
#   -0.18495069593191146,
#   -0.5281178832054139,
#   0.24607991352677344,
#   -0.27699386719614266,
#   -0.270410181581974,
#   -0.4294314995408058,
#   -0.057806722819805145,
#   0.08089195769280196,
#   0.15046067759394646,
#   0.5257092252373695,
#   -0.4308721497654915,
#   0.37830812633037564,
#   -0.3272769600152969,
#   0.35380709916353226,
#   0.040557943284511566,
#   1.5189249336719512,
#   0.30151415467262266,
#   0.06163212917745113,
#   -0.012240621820092203,
#   0.05660633314400911,
#   0.4585523456335068,
#   0.40311251282691957,
#   -0.27645366042852404,
#   0.7290101379156113,
#   0.0816301591694355,
#   0.4614270970225334,
#   -0.37843984924256796,
#   0.10476020351052283,
#   0.1940108023583889,
#   -0.14770002663135529,
#   0.3174493044614791,
#   -0.08391052419319749,
#   -0.29351732321083546,
#   -0.12550335489213466,
#   -0.2562810957431793,
#   -0.20104192942380905,
#   -0.0170846913009882,
#   0.42765667513012884,
#   -0.08936554118990897,
#   -0.25083267167210577,
#   -0.29563081860542295,
#   -0.06516076624393463,
#   0.09131053928285837,
#   -0.0018592506647110048,
#   0.1138370893895626,
#   -0.04312671665102243,
#   0.5116518169641495,
#   0.029257685691118238,
#   -0.10705575495958328,
#   -0.2240926880389452,
#   -0.35388399586081504,
#   0.0064205888658761985,
#   -0.6263511195778846,
#   -0.32254204675555226,
#   0.04507399201393127,
#   0.12574793100357054,
#   0.4746342703700065,
#   0.34590013474226]}

# %% [markdown]
# # Step Five: Index to Elastic Search

# %%
index_exists = es_bulk_indexer.check_index_existence(index_name=index_name)
if not index_exists:
    logger.info(f"Creating new index: {index_name}")
    es_bulk_indexer.create_es_index(es_configuration=BASIC_CONFIG, index_name=index_name)

success_count = es_bulk_indexer.bulk_upload_documents(
    index_name=index_name, 
    documents=chunked_documents, 
    id_col='id_',
    batch_size=32
)
# Out:
# INFO:elastic_transport.transport:HEAD https://95f1d816b5a34c759c6101b2858ddfda.asia-southeast1.gcp.elastic-cloud.com:443/test_index_1 [status:404 duration:0.163s]
# INFO:__main__:Creating new index: test_index_1
# INFO:elastic_transport.transport:HEAD https://95f1d816b5a34c759c6101b2858ddfda.asia-southeast1.gcp.elastic-cloud.com:443/test_index_1 [status:404 duration:0.008s]
# INFO:elastic_helpers:Index test_index_1 does not exist.
# INFO:elastic_transport.transport:PUT https://95f1d816b5a34c759c6101b2858ddfda.asia-southeast1.gcp.elastic-cloud.com:443/test_index_1 [status:200 duration:0.118s]
# INFO:elastic_helpers:New index test_index_1 created!
# INFO:elastic_transport.transport:PUT https://95f1d816b5a34c759c6101b2858ddfda.asia-southeast1.gcp.elastic-cloud.com:443/_bulk [status:200 duration:0.160s]
# INFO:elastic_helpers:Batch 1: Successfully indexed 32 documents to test_index_1
# INFO:elastic_transport.transport:PUT https://95f1d816b5a34c759c6101b2858ddfda.asia-southeast1.gcp.elastic-cloud.com:443/_bulk [status:200 duration:0.083s]
# INFO:elastic_helpers:Batch 2: Successfully indexed 32 documents to test_index_1
# INFO:elastic_transport.transport:PUT https://95f1d816b5a34c759c6101b2858ddfda.asia-southeast1.gcp.elastic-cloud.com:443/_bulk [status:200 duration:0.081s]
# INFO:elastic_helpers:Batch 3: Successfully indexed 32 documents to test_index_1
# INFO:elastic_transport.transport:PUT https://95f1d816b5a34c759c6101b2858ddfda.asia-southeast1.gcp.elastic-cloud.com:443/_bulk [status:200 duration:0.079s]
# INFO:elastic_helpers:Batch 4: Successfully indexed 32 documents to test_index_1
# INFO:elastic_transport.transport:PUT https://95f1d816b5a34c759c6101b2858ddfda.asia-southeast1.gcp.elastic-cloud.com:443/_bulk [status:200 duration:0.097s]
# INFO:elastic_helpers:Batch 5: Successfully indexed 32 documents to test_index_1
# INFO:elastic_transport.transport:PUT https://95f1d816b5a34c759c6101b2858ddfda.asia-southeast1.gcp.elastic-cloud.com:443/_bulk [status:200 duration:0.082s]
# INFO:elastic_helpers:Batch 6: Successfully indexed 32 documents to test_index_1
# INFO:elastic_transport.transport:PUT https://95f1d816b5a34c759c6101b2858ddfda.asia-southeast1.gcp.elastic-cloud.com:443/_bulk [status:200 duration:0.083s]
# INFO:elastic_helpers:Batch 7: Successfully indexed 32 documents to test_index_1
# INFO:elastic_helpers:Total documents successfully indexed to test_index_1: 224

# %% [markdown]
# # Step Six: Make a Query

# %%
def get_context(index_name, match_query, text_query, fields, num_candidates=100, num_results=20, text_fields=["original_text", 'keyphrases', 'potential_questions', 'entities'], embedding_field="primary_embedding"):
    embedding=embedder.get_embeddings_from_text(text_query)

    results, search_body = es_query_maker.hybrid_vector_search(
        index_name=index_name,
        query_text=match_query,
        query_vector=embedding[0][0],
        text_fields=text_fields,
        vector_field=embedding_field,
        num_candidates=num_candidates,
        num_results=num_results
    )
    context_docs=['\n\n'.join([field+":\n\n"+j['_source'][field] for field in fields]) for j in results['hits']['hits']]
    context_docs.reverse()
    return context_docs, search_body

# %%
def retrieval_augmented_generation(query_text):
    match_query= gpt4o.generate_query(query_text)
    fields=['original_text']

    hyde_document=gpt4o.generate_HyDE(query_text)

    context, search_body=get_context(index_name, match_query, hyde_document, fields)

    answer= gpt4o.basic_qa(query=query_text, context=context)
    return answer, match_query, hyde_document, context, search_body

# %% [markdown]
# # Test 1

# %%
query_text="who audits elastic"
answer, match_query, hyde_document, context, search_body = retrieval_augmented_generation(query_text)
print(answer)
# Out:
# INFO:llm:Executing task: Elastic Search Query Generation
# INFO:llm:Processing request with model: gpt-4o
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 200 OK"
# INFO:llm:Request processed successfully
# INFO:llm:Elastic search query generation completed successfully
# INFO:llm:Executing task: Elastic Search Query Generation
# INFO:llm:Processing request with model: gpt-4o
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 200 OK"
# INFO:llm:Request processed successfully
# INFO:llm:Elastic search query generation completed successfully
# INFO:elastic_transport.transport:POST https://training-9b4cc2.es.asia-southeast1.gcp.elastic-cloud.com:9243/test_index_1/_search [status:200 duration:0.041s]
# INFO:elastic_helpers:Hybrid search executed on index: test_index_1 with text query: audits elastic OR audit OR auditing OR auditor OR reviews OR examines OR inspects OR assesses OR evaluates OR certifies OR verifies OR analyzes OR examination OR inspection OR assessment OR evaluation OR certification OR verification OR analysis OR Elasticsearch OR ELK stack
# INFO:llm:Executing task: RAG answer generation
# INFO:llm:Processing request with model: gpt-4o
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 429 Too Many Requests"
# INFO:openai._base_client:Retrying request to /chat/completions in 16.000000 seconds
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 200 OK"
# INFO:llm:Request processed successfully
# INFO:llm:Rag answer generation completed successfully
# According to the context, the independent registered public accounting firm that audits Elastic N.V. is PricewaterhouseCoopers LLP (PwC). Here is the relevant excerpt:
#
# "[CLS] report of independent registered public accounting firm to the board of directors and shareholders of elastic n. v. [SEP] [CLS] opinions on the financial statements and internal control over financial reporting we have audited the accompanying consolidated balance sheets of elastic n. v. [SEP] [CLS] ... [SEP] [CLS] / s / pricewaterhouseco"
#
# PwC audited the consolidated financial statements as well as the company's internal control over financial reporting.

# %%
search_body
# Out:
# {'knn': {'field': 'primary_embedding',
#   'query_vector': [0.4265527129173279,
#    -0.1712949573993683,
#    -0.042020395398139954,
#    -0.5471225380897522,
#    0.4746799170970917,
#    -0.33410170674324036,
#    0.1717018485069275,
#    -0.4014941453933716,
#    -0.10174159705638885,
#    -0.09129292517900467,
#    0.06006495654582977,
#    -0.3378024101257324,
#    -0.11432260274887085,
#    -0.5213066339492798,
#    0.2760009467601776,
#    -0.09254149347543716,
#    -0.12062013149261475,
#    -0.5503711104393005,
#    0.43687838315963745,
#    0.7064043283462524,
#    0.45067155361175537,
#    -0.2836616039276123,
#       'fields': ['original_text',
#        'keyphrases',
#        'potential_questions',
#        'entities'],
#       'type': 'best_fields',
#       'operator': 'or'}}],
#    'should': [{'script_score': {'query': {'match_all': {}},
#       'script': {'source': '\n                                        double vector_score = cosineSimilarity(params.query_vector, params.vector_field) + 1.0;\n                                        double text_score = _score;\n                                        return 0.7 * vector_score + 0.3 * text_score;\n                                        ',
#        'params': {'query_vector': [0.4265527129173279,
#          -0.1712949573993683,
#          -0.042020395398139954,
#          -0.5471225380897522,
#          0.4746799170970917,
#          -0.33410170674324036,
#          0.1717018485069275,
#          -0.4014941453933716,
#          -0.10174159705638885,
#          -0.09129292517900467,
#          0.06006495654582977,
#          -0.3378024101257324,
#          -0.11432260274887085,
#          -0.5213066339492798,
#          0.2760009467601776,
#          -0.09254149347543716,
#          -0.12062013149261475,
#          -0.5503711104393005,
#          0.43687838315963745,
#          0.7064043283462524,
#          0.45067155361175537,
#          -0.2836616039276123,
#          -0.04662211239337921,
#          -0.20350763201713562,
#          0.010872878134250641,
#          0.5147824883460999,
#          -0.06530994921922684,
#          -0.3454621434211731,
#          -0.6738244891166687,
#          -1.3922719955444336,
#          0.0437544621527195,
#          -0.68052738904953,
#          0.05167144536972046,
#          0.03836928308010101,
#          0.01118258386850357,
#          -0.11759516596794128,
#          -0.39992353320121765,
#          -0.12960785627365112,
#          -0.04864056035876274,
#          -0.23949313163757324,
#          0.42291468381881714,
#          0.12774351239204407,
#          -0.006992820650339127,
#          -0.5431352257728577,
#          -0.05612806975841522,
#          -0.7988115549087524,
#          -0.010728105902671814,
#          -0.17103198170661926,
#          -0.1701931208372116,
#          0.3403394818305969,
#          -0.13591592013835907,
#          0.05660971999168396,
#          0.2625059485435486,
#          0.0652276873588562,
#          -0.023394063115119934,
#          0.08410204946994781,
#          0.39199233055114746,
#          0.3481012284755707,
#          0.10004828125238419,
#          -0.5481088161468506,
#          0.5432446002960205,
#          -0.18800148367881775,
#          -1.1664328575134277,
#          0.5552386045455933,
#          0.2891154885292053,
#          1.0122778415679932,
#          -0.23452603816986084,
#          -0.5295195579528809,
#          -0.2475910186767578,
#          -0.272242933511734,
#          -0.29271358251571655,
#          -0.2746065855026245,
#          -0.8054306507110596,
#          0.2559134066104889,
#          0.2644495666027069,
#          0.15946389734745026,
#          0.22430333495140076,
#          0.12155655026435852,
#          -0.3964439630508423,
#          0.0930689126253128,
#          -0.4714324474334717,
#          -0.4823061227798462,
#          -0.025941893458366394,
#          -0.27052855491638184,
#          0.5174427032470703,
#          0.1026795357465744,
#          0.057009872049093246,
#          -0.5088155269622803,
#          1.2263950109481812,
#          0.2927590608596802,
#          -0.09065819531679153,
#          -0.34790802001953125,
#          0.24438658356666565,
#          -0.1266469657421112,
#          0.47523409128189087,
#          -0.24842369556427002,
#          0.3071710467338562,
#          0.5082943439483643,
#          -0.09025149792432785,
#          2.965874433517456,
#          0.1744474172592163,
#          0.3583886921405792,
#          -0.15826693177223206,
#          -0.12257221341133118,
#          0.4816049635410309,
#          0.8028265833854675,
#          0.31715819239616394,
#          0.4037936329841614,
#          -0.36818554997444153,
#          0.3331034183502197,
#          0.7960338592529297,
#          0.6031477451324463,
#          -0.2218894362449646,
#          -0.07464415580034256,
#          -0.568490207195282,
#          -0.017219126224517822,
#          -0.38651034235954285,
#          0.015340864658355713,
#          0.1001853346824646,
#          -0.8021397590637207,
#          -0.6187012195587158,
#          -0.0997164398431778,
#          -0.003485884517431259,
#          0.23574873805046082,
#          0.05448145046830177,
#          0.20838740468025208,
#          0.022642353549599648,
#          -0.017417684197425842,
#          0.23163098096847534,
#          -0.307522177696228,
#          0.3160344362258911,
#          -0.07717389613389969,
#          -0.14784160256385803,
#          -0.16005319356918335,
#          0.39868640899658203,
#          -0.2648809552192688,
#          0.1473419964313507,
#          0.40052780508995056],
#         'vector_field': 'primary_embedding'}}}}]}},
#  'size': 10}

# %% [markdown]
# # Test 2

# %%
query_text="total revenue 2023"
answer, match_query, hyde_document, context, search_body = retrieval_augmented_generation(query_text)
print(answer)
# Out:
# INFO:llm:Executing task: Elastic Search Query Generation
# INFO:llm:Processing request with model: gpt-4o
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 200 OK"
# INFO:llm:Request processed successfully
# INFO:llm:Elastic search query generation completed successfully
# INFO:llm:Executing task: Elastic Search Query Generation
# INFO:llm:Processing request with model: gpt-4o
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 200 OK"
# INFO:llm:Request processed successfully
# INFO:llm:Elastic search query generation completed successfully
# INFO:elastic_transport.transport:POST https://training-9b4cc2.es.asia-southeast1.gcp.elastic-cloud.com:9243/test_index_1/_search [status:200 duration:0.038s]
# INFO:elastic_helpers:Hybrid search executed on index: test_index_1 with text query: total revenue 2023 OR total income 2023 OR gross revenue 2023 OR net revenue 2023 OR gross income 2023 OR net income 2023 OR earnings 2023 OR profits 2023 OR sales 2023
# INFO:llm:Executing task: RAG answer generation
# INFO:llm:Processing request with model: gpt-4o
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 200 OK"
# INFO:llm:Request processed successfully
# INFO:llm:Rag answer generation completed successfully
# According to the provided context, the total revenue for the fiscal year ended April 30, 2023, was $1,068,989,000.
#
# Quoting directly from the source:
# "The following table presents revenue by category ( in thousands ) : year ended April 30, 2023 [...] total revenue $ 1, 068, 989 100 %"
#
# Additionally, in the consolidated statements of operations:
# "total revenue 1, 068, 989 862, 374 608, 489"
#
# Thus, the total revenue for the fiscal year 2023 is $1,068,989,000.

# %% [markdown]
# # Test 3

# %%
query_text="what product does growth primarily depend on? How much"
answer, match_query, hyde_document, context, search_body = retrieval_augmented_generation(query_text)
print(answer)
# Out:
# INFO:llm:Executing task: Elastic Search Query Generation
# INFO:llm:Processing request with model: gpt-4o
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 200 OK"
# INFO:llm:Request processed successfully
# INFO:llm:Elastic search query generation completed successfully
# INFO:llm:Executing task: Elastic Search Query Generation
# INFO:llm:Processing request with model: gpt-4o
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 200 OK"
# INFO:llm:Request processed successfully
# INFO:llm:Elastic search query generation completed successfully
# INFO:elastic_transport.transport:POST https://training-9b4cc2.es.asia-southeast1.gcp.elastic-cloud.com:9243/test_index_1/_search [status:200 duration:0.044s]
# INFO:elastic_helpers:Hybrid search executed on index: test_index_1 with text query: product growth OR product development OR product success OR product performance OR product impact OR product influence OR business growth OR company growth OR sales growth OR market growth OR revenue growth OR profitability OR financial performance OR business performance OR sales figures OR market performance OR economic performance OR depend OR relies OR based on OR contingent on OR influenced by OR driven by OR dictated by OR how much OR amount OR extent
# INFO:llm:Executing task: RAG answer generation
# INFO:llm:Processing request with model: gpt-4o
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 200 OK"
# INFO:llm:Request processed successfully
# INFO:llm:Rag answer generation completed successfully
# ### Products Driving Growth
# According to the provided information, the company's growth primarily depends on the "elastic stack." This is evident from multiple sections of the context. For instance:
#
# 1. **Revenue Source:**
#    - "Our revenue is derived primarily from subscriptions of search, observability and security built into the elastic stack."
#
# 2. **Future Investments:**
#    - "We believe that releasing additional features of the elastic stack, including our solutions, drives usage of our products and ultimately drives our growth."
#    - "To that end, we plan to continue to invest in building new features and solutions that expand the capabilities of the elastic stack."
#
# These points collectively indicate that the company's growth is heavily reliant on the functionality, enhancements, and adoption of the elastic stack.
#
# ### Extent of Dependence
# The context provides quantitative data on revenue growth, but it does not specify how much growth is projected or quantified specifically for the elastic stack alone. However, it does state the significant role of subscriptions in overall revenue:
#
# 1. **Overall Revenue and Growth:**
#    - "Our total revenue was $1.1 billion, $862.4 million, and $608.5 million for the years ended April 30, 2023, 2022 and 2021, respectively, representing year-over-year growth of 24% for the year ended April 30, 2023 and 42% for the year ended April 30, 2022."
#    - "Subscriptions accounted for 92%, 93% and 93% of our total revenue for the years ended April 30, 2023, 2022 and 2021, respectively."
#
# ### Summary
# The company's growth primarily depends on the "elastic stack," particularly its features related to search, observability, and security. While exact figures concerning the specific contribution of the elastic stack to growth aren't provided, it's clear that a significant portion of the company's revenue and growth strategy revolves around it.

# %% [markdown]
# # Test 4

# %%
query_text="Describe employee benefit plan"
answer, match_query, hyde_document, context, search_body = retrieval_augmented_generation(query_text)
print(answer)
# Out:
# INFO:llm:Executing task: Elastic Search Query Generation
# INFO:llm:Processing request with model: gpt-4o
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 200 OK"
# INFO:llm:Request processed successfully
# INFO:llm:Elastic search query generation completed successfully
# INFO:llm:Executing task: Elastic Search Query Generation
# INFO:llm:Processing request with model: gpt-4o
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 200 OK"
# INFO:llm:Request processed successfully
# INFO:llm:Elastic search query generation completed successfully
# INFO:elastic_transport.transport:POST https://training-9b4cc2.es.asia-southeast1.gcp.elastic-cloud.com:9243/test_index_1/_search [status:200 duration:0.191s]
# INFO:elastic_helpers:Hybrid search executed on index: test_index_1 with text query: employee benefit plan OR employee benefits OR employee compensation OR benefits plan OR health benefits OR retirement plan OR pension plan OR health insurance OR dental insurance OR vision insurance OR life insurance OR disability insurance OR wellness program OR 401k OR 403b OR profit-sharing plan OR stock options OR paid time off OR PTO OR sick leave OR vacation time OR parental leave OR employee perks OR employee rewards OR fringe benefits OR employee assistance program
# INFO:llm:Executing task: RAG answer generation
# INFO:llm:Processing request with model: gpt-4o
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 200 OK"
# INFO:llm:Request processed successfully
# INFO:llm:Rag answer generation completed successfully
# ### Employee Benefit Plan Overview
#
# The provided context outlines various elements of the employee benefit plan at Elastic, often referred to as "Elasticians." Here are the key components described in the texts:
#
# 1. **401(k) Plan**:
#    - **Coverage**: The 401(k) plan is available to substantially all U.S. employees who meet minimum age and service requirements.
#    - **Contributions**: Elastic makes contributions to the 401(k) plan up to 6% of the participating employee’s W-2 earnings and wages.
#    - **Expenses**: For the fiscal years ended April 30, Elastic recorded expenses of $17.9 million (2023), $15.2 million (2022), and $11.4 million (2021) related to the 401(k) plan.
#    - **Defined-Contribution Plans in Other Countries**: Elastic has defined-contribution plans in various other countries and recorded respective expenses of $9.4 million (2023), $7.2 million (2022), and $5.1 million (2021).
#
# 2. **Stock-Based Compensation**:
#    - **Types of Awards**: Stock options, restricted stock units (RSUs), and shares under the Employee Stock Purchase Plan (ESPP).
#    - **Fair Value Measurement**: Fair value of these stock awards is measured using models like Black-Scholes.
#    - **Employee Stock Purchase Plan (2022 ESPP)**:
#      - Started in 2022, it allows employees to acquire ordinary shares at a discount (85% of the market value at the beginning or end of the offering period).
#      - Offering periods are approximately six months long.
#
# 3. **Total Rewards Compensation**:
#    - **Components**: Includes cash compensation as well as equity awards, reflecting a comprehensive interest in the well-being of the employees.
#    - **Programs**: Market competitive medical and dental programs, mental health, and holistic well-being programs.
#    - **Paid Time Off**: Features 16 weeks of paid leave for new parents and life-planning benefits.
#
# 4. **Retirement and Income Protection Plans**:
#    - **401(k) Match**: Elastic provides a dollar-for-dollar match up to 6% of eligible earnings up to a plan-limit maximum for U.S.-based employees.
#    - **Similar Plans Outside the U.S.**: Competitive retirement plans available for employees based outside the United States.
#
# 5. **Flexible Work Environment**:
#    - **Distributed Workforce**: Elastic operates with a global distributed workforce model, allowing employees to work remotely and providing a broad candidate pool.
#
# 6. **Learning and Development**:
#    - **Programs**: Access to on-demand video-based learning, leadership development programs, and other specific training to develop managers and leaders.
#
# 7. **Employee Engagement and Surveys**:
#    - **Mechanisms**: Annual employee engagement survey and mid-year pulse survey.
#    - **Objectives**: To monitor morale, develop action plans, and maintain high engagement scores.
#
# 8. **Onboarding Program**:
#    - **X-School**: An extensive new-hire orientation program to help new employees meet peers and learn about the company's products and solutions.
#
# In summary, Elastic's employee benefit plan encompasses a broad spectrum of financial, health, well-being, and professional development benefits designed to support and enhance the lives of its employees. The plan is both competitive and comprehensive, aiming to attract, retain, and engage its global workforce.

# %% [markdown]
# # Test 5

# %%
query_text="Which companies did Elastic acquire?"
answer, match_query, hyde_document, context, search_body = retrieval_augmented_generation(query_text)
print(answer)
# Out:
# INFO:llm:Executing task: Elastic Search Query Generation
# INFO:llm:Processing request with model: gpt-4o
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 200 OK"
# INFO:llm:Request processed successfully
# INFO:llm:Elastic search query generation completed successfully
# INFO:llm:Executing task: Elastic Search Query Generation
# INFO:llm:Processing request with model: gpt-4o
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 200 OK"
# INFO:llm:Request processed successfully
# INFO:llm:Elastic search query generation completed successfully
# INFO:elastic_transport.transport:POST https://training-9b4cc2.es.asia-southeast1.gcp.elastic-cloud.com:9243/test_index_1/_search [status:200 duration:0.036s]
# INFO:elastic_helpers:Hybrid search executed on index: test_index_1 with text query: Elastic acquire OR acquired OR acquisition OR acquisitioned OR buy OR bought OR purchase OR purchased OR merger OR merged OR obtain OR obtained OR companies OR company OR firm OR firms OR organizations OR businesses
# INFO:llm:Executing task: RAG answer generation
# INFO:llm:Processing request with model: gpt-4o
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 429 Too Many Requests"
# INFO:openai._base_client:Retrying request to /chat/completions in 18.000000 seconds
# INFO:httpx:HTTP Request: POST https://ca-shared.openai.azure.com//openai/deployments/experiment_45kTPM_gpt-4o/chat/completions?api-version=2024-06-01 "HTTP/1.1 200 OK"
# INFO:llm:Request processed successfully
# INFO:llm:Rag answer generation completed successfully
# Elastic acquired several companies over the years to enhance its technology and market presence. According to the provided context, the specific acquisitions include:
#
# 1. **CmdWatch Security Inc.**: Acquired on September 17, 2021. The total purchase consideration was $77.8 million.
# 2. **Build Security Ltd.**: Acquired on September 2, 2021. The combined purchase price for Build Security Ltd. and another acquisition was $57.2 million.
# 3. **Optimyze Cloud Inc.**: Acquired on November 1, 2021. Part of the combined purchase price mentioned above with Build Security Ltd.
# 4. **Endgame, Inc.**: Although the context mentions an amended and restated stock incentive plan, it indicates that Endgame, Inc. was associated with Elastic, suggesting it could have been acquired at some point.
#
# These acquisitions are part of Elastic's strategy to enhance the technology underlying its security and observability offerings.

# %%
match_query
# Out:
# 'companies Elastic OR Elastic acquired OR acquisitions OR acquisition OR purchase OR purchases OR bought OR buy OR buys'
